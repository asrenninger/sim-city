# %% [markdown]
# # Synthetic Cities: Comparing Urban Morphologies
#
# This notebook compares mobility outcomes across different synthetic city types:
# - Monocentric
# - Polycentric
# - Urban villages
# - Edge city
# - Grid (null model)

# %%
from sim_city import SimulationConfig, MobilitySimulation
from sim_city.spatial import SyntheticCity
from sim_city.viz import plot_comparison

# %%
# TODO: Implement city morphology comparison
