# %% [markdown]
# # Quickstart: Basic Synthetic City Simulation
#
# This notebook demonstrates the basic workflow for simulating mobility in a synthetic city.

# %%
from sim_city import SimulationConfig, MobilitySimulation
from sim_city.spatial import SyntheticCity

# %%
# TODO: Implement quickstart example
