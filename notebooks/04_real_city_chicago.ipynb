# %% [markdown]
# # Real City: Chicago Full Pipeline
#
# This notebook demonstrates the complete pipeline for simulating mobility in a real city using:
# - Overture Places POIs
# - US Census population data
# - Census tract boundaries

# %%
from sim_city import SimulationConfig, MobilitySimulation
from sim_city.spatial import RealCity
from sim_city.io import load_fuas, bbox_from_fua

# %%
# TODO: Implement Chicago real city pipeline
