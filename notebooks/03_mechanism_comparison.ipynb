# %% [markdown]
# # Mechanism Comparison: Toggle EPR, Recency, Capacity
#
# This notebook explores how different mobility mechanisms affect simulation outcomes:
# - Exploration-Preferential Return (EPR)
# - Recency effects
# - Location capacity constraints

# %%
from sim_city import SimulationConfig, MobilitySimulation
from sim_city.spatial import SyntheticCity
from sim_city.viz import plot_comparison

# %%
# TODO: Implement mechanism comparison experiments
