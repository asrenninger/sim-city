# %% [markdown]
# # Urban Mobility Simulation: Comparing City Archetypes
#
# This notebook compares mobility across different observed cities:
#
# - Vienna
# - Toulouse
# - Budapest
# - Copenhagen
# - Turino

# %%
from sim_city import *
